# %% [markdown]
# # Assessment of nucleotide-binding site configurations in structures of P-loop NTPases

# %% [markdown]
# Pipeline of the analysis described in [@kozlovaUnitedDiversityPatterns2022] and [@kozlovaUnitedDiversityCommonality2022].
# The routine uses BioPython PDB module to open PDBs and Pfam/Uniprot mappings to assign Superfamily information.

# %% [markdown]
# ## Imports
# Running the routine requires Biopython v.  1.79 and Pandas v. 1.2.2 to be installed.

# %%
import os
import pandas as pd

# %% [markdown]
# ## 0. Input files & setup

# %% [markdown]
# ### 0.1 Path definitions
# Input files used are provided in this repo in the "ploop_input" folder

# %%
### Working directory ###
ploop_wdir="/home/servalli/Documents/projects/Ploop_autogenerated"

##subdirs
pdb_dir="PDB"
log_dir="logs"

if not os.path.isdir(ploop_wdir):
    os.mkdir(ploop_wdir)
    
for dir_p in [pdb_dir,log_dir]:
    if not os.path.isdir(os.path.join(ploop_wdir,dir_p)):
        os.mkdir(os.path.join(ploop_wdir,dir_p))


#######PATH DEFINITIONS
p_dir=os.path.join(ploop_wdir,pdb_dir) #PDB folder 

###Input files ###

ploop_in_dir="ploop_input" #folder with all input text files
ploop_chain_list_p=os.path.join(ploop_in_dir, "ploop_list.txt")  #Interpro mapping by PDB ID and chain, tab-delimited table: 121p	A	IPR027417

compound_dir="compound_lists" #folder with lists of PDBs with a given ligand, taken from RCSB PDB (no headers allowed!)
ion_cont_p="MG_MN_SR_CA.txt" #All structures containing Mg2+, Mn2+, Sr2+, Ca2+, retrieved from RCSB PDB
###Family mappings 
pf_dir="ploop_input/pf_ploop_assignment" #Subfolder with Pfam Mappings
pth_pdb_mapping="pdbmap"   #from ftp://ftp.ebi.ac.uk/pub/databases/Pfam/current_release/pdbmap.gz
pth_suprfam="ploop_pfam_to_superfam.csv" #Pfam domains manually assigned to major classes of P-loop NTPases
up_txt="uniprot-pdb.tab" ###Uniprot descriptions as table retrieved from Uniprot website 13/10/2020
up_mapping="pdb_chain_uniprot.lst" ###NEW MAPPING RETRIEVED 10/10/2020 from ftp://ftp.ebi.ac.uk/pub/databases/msd/sifts/text/pdb_chain_uniprot.lst
pf_mapping="pdb_chain_pfam.lst" ###RETRIEVED 13/10/2020 from ftp://ftp.ebi.ac.uk/pub/databases/msd/sifts/text/pdb_chain_pfam.lst
pf_hmmer="hmmer_pdb_all.txt" ###retrieved from http://www.rcsb.org/pdb/rest/hmmer?file=hmmer_pdb_all.txt used for Pfam domain coordinates
interpro_mapping="pdb_chain_interpro.tsv"
sites_checked="sites_checked_manually.txt" #Table listing sites we checked manually on the previous run, listing the information on Arg finger binding type

# %% [markdown]
# ### 0.2 Setup for a run
# Read input id lists, select PDBs to be downloaded:

# %%
d_ip_mapping=pd.read_csv(os.path.join(pf_dir, interpro_mapping), sep="\t", header=1, names=["pdbid","chain","ipr"])

ploop_all_chains=d_ip_mapping[d_ip_mapping.ipr=="IPR027417"].copy()
ploop_all_chains['ind_ch']=['_'.join([x, y]) for x, y in zip(ploop_all_chains['pdbid'], ploop_all_chains['chain'])]

# %% [markdown]
# Filter P-loop structures by ligand type (only nucleotide/nucleotide analog and some divalent cation bound).<br>
# Structures with ADP/GDP are only selected if there is a mimic of γ-phosphate bound in the same structure.<br>
# Nucleotide analogs analyzed include following compounds:
# * ATP
# * GTP
# * ATP-γ-S (AGS)
# * AMP-PNP (ANP)
# * AMP-PCP (ACP)
# * GTP-γ-S (GSP)
# * GMP-PNP (GNP)
# * GMP-PCP (GCP)
# * ADP and GDP if complexed with:
#     * BeF<sub>3</sub> (BEF)
#     * MgF<sub>3</sub><sup>-</sup> (MGF)
#     * AlF<sub>3</sub> (AF3)
#     * AlF<sub>4</sub><sup>-</sup> (ALF)
#     * VO<sub>4</sub><sup>3-</sup> (VO4)

# %%
#PDBs with ligands lists, taken from RCSB PDB website (9/10/20)

with open(os.path.join(ploop_in_dir,compound_dir,ion_cont_p),"r") as f: has_ion=set(f.readline().strip("\n").split(","))

#with open(os.path.join(ploop_in_dir,interpro_p),"r") as f:   interpro_ids={l.strip("\n").split("\t")[0].upper() for l in f.readlines()}
interpro_ids=set(ploop_all_chains.pdbid.str.upper().to_list())

trinuc_ids=["ATP","ACP","AGS","ANP","GTP","GNP","GSP","GCP"]
compound_pdb={}
for c_id in trinuc_ids:
    with open(os.path.join(ploop_in_dir,compound_dir,f"{c_id}.txt"),"r") as f:
        pdbs=set(f.readline().strip("\n").split(","))
        pdbs_suitable=sorted(list(pdbs&has_ion&interpro_ids))
        compound_pdb[c_id]=pdbs_suitable

gamma_ids=["MGF","ALF","AF3","BEF","VO4"]
gamma_list=[]
for gamma in gamma_ids:
    with open(os.path.join(ploop_in_dir,compound_dir,f"{gamma}.txt"),"r") as f: cur_gamma=f.readline().strip("\n").split(",")
    gamma_list.extend(cur_gamma)
gamma_list=set(gamma_list)
dinuc_ids=["ADP","GDP"]
for c_id in dinuc_ids:
    with open(os.path.join(ploop_in_dir,compound_dir,f"{c_id}.txt"),"r") as f:
        pdbs=set(f.readline().strip("\n").split(","))
        pdbs_suitable=sorted(list(pdbs&has_ion&interpro_ids&gamma_list))
        compound_pdb[c_id]=pdbs_suitable

# %% [markdown]
# ## 1. Download structures

# %%
from pyploop.process_pdb import download_pdbs
downloaded=download_pdbs(compound_pdb, ploop_wdir, pdb_dir, log_dir)

# %%
print (f"Total {downloaded.shape[0]}, unique {downloaded.PDBID.unique().shape[0]}") 
downloaded.groupby("nucl").count()
# Out:
# Total 1615, unique 1566
#       PDBID
# nucl
# ACP      22
# ADP     144
# AGS      64
# ANP     191
# ATP     285
# GCP      69
# GDP      89
# GNP     416
# GSP      75
# GTP     260

# %% [markdown]
# ## 2. Calculate the distances

# %% [markdown]
# ### For each PDB,
# * Structure metadata was retrieved, low-resolution models (>5Å) skipped
# * For each structure, surroundings of each nucleotide(/nucleotide-like compound) were analyzed.

# %% [markdown]
# #### Each nucleotide was processed in the following way:
# * Find γ-phosphate or a moeity mimicking it.
# * Find Mg2+ or other divalent cation (Ca, Mn, Sr...)
# * Find Walker A Lys by proximity to beta-phosphate and sequence check.
# * Find Walker A Ser\Thr by sequence, measure distance to Mg<sup>2+</sup>
# * List availability of H2O in the structure
# * Find Walker B Asp/Glu by distance in relation to [S/T]<sup>K+1</sup>, performing a hydrophobicity check
# for three preceding residues (not allowing E,D,S,T,Y,K,R,H). If no suitable Asp/Glu was found in 5Å from [S/T]<sup>K+1</sup>, the closest residue is listed. The distance to [S/T]<sup>K+1</sup> is recorded.
# * Find putative finger residues - list closest Arg, non-P-loop Lys, Asn residues (by proximity to β-phosphate)
# * List all protein nitrogens in 4Å from γ-phosphate.

# %% [markdown]
# ### 2.1 Definitions for distance calculations:

# %%
comps=["ADP","ATP","ANP","ACP","AGS","GNP","GCP","GSP","GTP","GDP"] #Nucleotide analogs types to be processed
comps_F=["GDP","ADP"] #nucleoside diphosphates
###Atom names
beta=["O1B","O2B","O3B","N3B","C3B"]
alpha=["O1A","O2A","O3A"] 
gamma_N=["O1G","O2G","O3G","S1G"]
gamma_F=["F1","F2","F3","F4","O1","O2","O3","O4"]
#Types of γ-phosphate mimics
gamma_types=["ALF","AF3","BEF","MGF","VO4"]

# %% [markdown]
# ### 2.2 Calculate distances

# %%
from pyploop.process_pdb import process_pdb_dir
dists=process_pdb_dir(p_dir,comps, comps_F, alpha, beta,  gamma_F, gamma_N, gamma_types,ploop_all_chains)
# Out:
# ADP 144 structures of P-loop NTPases available
# 0 1br1 ADP
# Gamma not found! 1h8e ADP A600, skipping
# Gamma not found! 1h8e ADP B600, skipping
# Gamma not found! 1h8e ADP C600, skipping
# Gamma not found! 1h8e ADP E600, skipping
# Gamma not found! 1ihu ADP A590, skipping
# Gamma not found! 1vfz ADP A500, skipping
# Gamma not found! 1w0j ADP A1511, skipping
# Gamma not found! 1w0j ADP B1511, skipping
# Gamma not found! 1w0j ADP C1511, skipping
# 50 3kql ADP
# 100 5lta ADP
# Gamma not found! 6ap1 ADP D701, skipping
# Gamma not found! 6ap1 ADP E701, skipping
# Gamma not found! 6bmf ADP D501, skipping
# Gamma not found! 6bmf ADP E501, skipping
# Gamma not found! 6gej ADP T501, skipping
# Gamma not found! 6gej ADP U502, skipping
# Gamma not found! 6gej ADP V501, skipping
# Gamma not found! 6gej ADP W501, skipping
# Gamma not found! 6gej ADP X501, skipping
# Gamma not found! 6gej ADP Y501, skipping
# Gamma not found! 6gen ADP T501, skipping
# Gamma not found! 6gen ADP U502, skipping
# Gamma not found! 6gen ADP V501, skipping
# Gamma not found! 6gen ADP W501, skipping
# Gamma not found! 6gen ADP X501, skipping
# Gamma not found! 6gen ADP Y502, skipping
# Gamma not found! 6ndy ADP D501, skipping
# Gamma not found! 6ndy ADP E501, skipping
# Gamma not found! 6omb ADP E901, skipping
# Gamma not found! 6omb ADP E902, skipping
# Gamma not found! 6oo2 ADP D501, skipping
# Gamma not found! 6oo2 ADP E501, skipping
# Gamma not found! 6opc ADP E901, skipping
# Gamma not found! 6opc ADP E902, skipping
# Gamma not found! 6pek ADP E701, skipping
# Gamma not found! 6pen ADP E701, skipping
# ATP 285 structures of P-loop NTPases available
# 0 1a82 ATP
# 50 2vhq ATP
# 100 4m9x ATP
# 150 5oiu ATP
# 200 6msb ATP
# 250 6rdw ATP
# ANP 191 structures of P-loop NTPases available
# 0 1bmf ANP
# 50 2jlr ANP
# Gamma not found! 3puz ANP A2501, skipping
# Gamma not found! 3puz ANP B2502, skipping
# 100 3zfc ANP
# 150 5kiy ANP
# Gamma not found! 6d6q ANP M2001, skipping
# Gamma not found! 6d6r ANP M2001, skipping
# ACP 22 structures of P-loop NTPases available
# 0 1dah ACP
# Warning! Truncated nucleotides (no beta-phosphate) 4kfu A ['ACP302']
# Warning! Truncated nucleotides (no beta-phosphate) 4kfu B ['ACP302']
# Warning! Truncated nucleotides (no beta-phosphate) 4kfu C ['ACP301']
# Warning! Truncated nucleotides (no beta-phosphate) 4kfu D ['ACP301']
# AGS 64 structures of P-loop NTPases available
# 0 1bif AGS
# Warning! Truncated nucleotides (no beta-phosphate) 4kft A ['AGS301']
# Gamma not found! 4kft AGS A302, skipping
# Warning! Truncated nucleotides (no beta-phosphate) 4kft B ['AGS302']
# Gamma not found! 4kft AGS B301, skipping
# Gamma not found! 4kft AGS C301, skipping
# Gamma not found! 4kft AGS D301, skipping
# 50 5zt1 AGS
# GNP 416 structures of P-loop NTPases available
# 0 1agp GNP
# 50 1svs GNP
# 100 2mse GNP
# 150 3oiv GNP
# 200 4dlr GNP
# 250 4q66 GNP
# 300 5lzb GNP
# 350 621p GNP
# 400 6huf GNP
# GCP 69 structures of P-loop NTPases available
# 0 121p GCP
# 50 5uyq GCP
# GSP 75 structures of P-loop NTPases available
# 0 1a2b GSP
# 50 4tn1 GSP
# GTP 260 structures of P-loop NTPases available
# 0 1c1y GTP
# 50 2wbe GTP
# 100 4hna GTP
# 150 5k7x GTP
# 200 6a3b GTP
# Gamma not found! 6iae GTP A301, skipping
# Gamma not found! 6iae GTP B301, skipping
# 250 6qw6 GTP
# GDP 89 structures of P-loop NTPases available
# 0 1fqj GDP
# Gamma not found! 4c7o GDP D1306, skipping
# 50 4ekc GDP

# %%
dists_raw=dists.copy()
year=2022
spec="Ver5_hy_fallback"
dists.to_csv(os.path.join(ploop_wdir,f"{year}_{spec}_t1_raw_dist.tsv"),sep="\t")

# %% [markdown]
# This is what we get:

# %%
dists[dists.columns[8:]].head()
# Out:
#   PDBID model nuc_type nuc_chain nuc_id nuc_gamma_moiety_type  \
# 0  1br1     0      ADP         A    998                   ALF
# 1  1br1     0      ADP         C    998                   ALF
# 2  1br1     0      ADP         E    998                   ALF
# 3  1br1     0      ADP         G    998                   ALF
# 4  1br2     0      ADP         A    998                   ALF
#
#   nuc_gamma_moiety_chain nuc_gamma_moiety_id mg_in_site_4a_from_beta AG-site  \
# 0                      A                 999                      MG     NaN
# 1                      C                 999                      MG     NaN
# 2                      E                 999                      MG     NaN
# 3                      G                 999                      MG     NaN
# 4                      A                 999                      MG     NaN
#
#   G-site TYPE_ARG LYS-site asn_TYPE Lys_res_ch Lys_res_id nz-alpha-atom  \
# 0    NaN      NaN      NaN                   A        250           O1A
# 1    NaN      NaN      NaN                   C        250           O1A
# 2    NaN      NaN      NaN                   E        250           O1A
# 3    NaN      NaN      NaN                   G        250           O1A
# 4    NaN      NaN      NaN                   A        250           O1A
#
#   nz-alpha-dist nz-gamma-atom nz-gamma-dist Arg_res_ch Arg_res_id  \
# 0      8.639585            F4      7.628103          A        247
# 1      8.718588            F4      7.675519          C        247
# 2      8.767497            F4      7.666852          E        247
# 3      8.785262            F4      7.654045          G        247
# 4      8.386499            F4      7.087786          A        247
#
#   nh1-alpha-atom nh1-alpha-dist nh1-gamma-atom nh1-gamma-dist nh2-alpha-atom  \
# 0            O2A      10.024054             F3        5.33214            O2A
# 1            O2A       9.955953             F3       5.308627            O2A
# 2            O2A      10.116271             F3       5.496902            O2A
# 3            O2A      10.132792             F3       5.477052            O2A
# 4            O3A       9.803608             F3       4.609398            O3A
#
#   nh2-alpha-dist nh2-gamma-atom nh2-gamma-dist ne-alpha-atom ne-alpha-dist  \
# 0      11.278693             F3       6.160625           O2A     10.615997
# 1      11.298747             F3       6.233797           O2A     10.617236
# 2       11.47034             F3       6.434052           O2A      10.82166
# 3      11.498631             F3       6.433871           O2A     10.795943
# 4      12.066981             F3       6.799509           O2A     11.023004
#
#   ne-gamma-atom ne-gamma-dist asn_ID asn_ne2-alpha-atom asn_ne2-alpha-dist  \
# 0            F3         6.615   A242                O2A           2.916646
# 1            F3       6.68114   C242                O2A           2.969201
# 2            F3       6.89429   E242                O2A           3.156481
# 3            F3      6.833364   G242                O2A           3.129764
# 4            F3      6.514483   A242                O2A           2.941894
#
#   asn_ne2-gamma-atom asn_ne2-gamma-dist  \
# 0                 F2           3.817497
# 1                 F2           3.955435
# 2                 F2           3.965111
# 3                 F2           3.859841
# 4                 F2           3.716788
#
#                                            Surr_N_BB Surr_N_SCh gly13-chain  \
# 0             GLY_A468..F1(2.55); SER_A246..F2(2.70)                      A
# 1             GLY_C468..F1(2.46); SER_C246..F2(2.75)                      C
# 2  GLY_E468..F1(2.48); SER_E179..F1(3.99); SER_E2...                      E
# 3             GLY_G468..F1(2.53); SER_G246..F2(2.78)                      G
# 4             GLY_A468..F1(2.54); SER_A246..F2(2.58)                      A
#
#   gly13-type gly13-id nuc-to-g13-atom dist-gly13 lys-ploop-info ploopk-dist  \
# 0        GLY      180              F1   3.655413           A183    2.780986
# 1        GLY      180              F1   3.738719           C183    2.751563
# 2        GLY      180              F1   3.665947           E183    2.710544
# 3        GLY      180              F1   3.664732           G183    2.774285
# 4        GLY      180              F3   3.980544           A183    2.752079
#
#   resolution             method  \
# 0        3.5  x-ray diffraction
# 1        3.5  x-ray diffraction
# 2        3.5  x-ray diffraction
# 3        3.5  x-ray diffraction
# 4        2.9  x-ray diffraction
#
#                                              pdbname     pdbdate include  \
# 0  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 1  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 2  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 3  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 4  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN COMPLEXED WI...  1998-08-26     NaN
#
#   SerK+1-Mg WB-Asp/Glu WBD-SerK+1_dist    WBD-Mg water_present is_hydro  \
# 0  2.159976   ASP_A465        3.946227  3.889449          True     True
# 1  2.166397   ASP_C465        3.922912  3.763648          True     True
# 2  2.076092   ASP_E465        3.938586  3.718373          True     True
# 3  2.066263   ASP_G465        3.922849  3.771162          True     True
# 4  2.013697   ASP_A465        2.795241  3.434139          True     True
#
#   preceding_res
# 0           LIG
# 1           LIG
# 2           LIG
# 3           LIG
# 4           LIG

# %% [markdown]
# ## 3. Add Annotations

# %% [markdown]
# ### 3.1 Read tables for annotation

# %%
#Mapping from PDB to Pfam
d_pfam_mapping=pd.read_csv(os.path.join(pf_dir, pf_mapping), sep="\t", header=1)
#Results of HMMer run against sequences from PDB, with coordinates
d_pfam_hmm=pd.read_csv(os.path.join(pf_dir, pf_hmmer), sep="\t", header=0)

d_pfam_hmm["PFAM"]=d_pfam_hmm.PFAM_ACC.str.split(".",expand=True)[0]
d_pfam_hmm[["start","end"]]=-10000000,10000000
isnumeric_start=d_pfam_hmm.PdbResNumStart.str.lstrip("-").str.isdigit()
isnumeric_end=d_pfam_hmm.PdbResNumEnd.str.lstrip("-").str.isdigit()
d_pfam_hmm.loc[isnumeric_start,"start"]=d_pfam_hmm.loc[isnumeric_start,"PdbResNumStart"].astype(int)
d_pfam_hmm.loc[isnumeric_end,"end"]=d_pfam_hmm.loc[isnumeric_end,"PdbResNumEnd"].astype(int)
d_pfam_hmm.sort_values(by="eValue", inplace=True)
col_ns_pdb_pf=['PDB_ID','CHAIN_ID',2,"PFAM_Name", "PFAM_ACC","Accesion", "Position"]
#Another Pfam-PDB mapping
pf_to_pdb = pd.read_csv(os.path.join(pf_dir, pth_pdb_mapping), sep="\t", header=None, names=col_ns_pdb_pf)
for col in pf_to_pdb:
	if col!=2:		
		pf_to_pdb[col] = pf_to_pdb[col].map(lambda x: x.strip(';'))		
#Pfam domains to P-loop NTPase classes (superfamilies)	
pf_to_suprf=pd.read_csv(os.path.join(pf_dir, pth_suprfam), sep=",", header=0)
accesions=list(pf_to_suprf['pf_id'])
pdbs_ploop=pf_to_pdb.loc[pf_to_pdb["PFAM_ACC"].isin(accesions)].copy()
pdbs_ploop['pdb_id']=pdbs_ploop['PDB_ID'].str.lower()
pdb_to_up={}

#Uniprot info & mapping to PDB
d_up_info=pd.read_csv(os.path.join(pf_dir, up_txt), sep="\t", header=0)
d_up_mapping=pd.read_csv(os.path.join(pf_dir, up_mapping), sep="\t", header=1)

# %% [markdown]
# ### 3.2 Filter site table and add protein descriptions

# %%
from pyploop.table_features import mark_lowqual_sites, add_identifiers

# %% [markdown]
# <br>Assign Uniprot IDs and Superfamily data. Pfam mapping is used to assign sites to major classes of P-loop NTPases, for this Pfam domains of CL00023 were assigned to classes (i.e. "TRAFAC" or "AAA+")  manually, see example below.</br>

# %%
pf_to_suprf.head(10)
# Out:
#      n    pf_id           domain         syn  \
# 0  NaN  PF06431   Polyoma_lg_T_C         NaN
# 1    s  PF00004              AAA         NaN
# 2    s  PF13191           AAA_16         NaN
# 3    s  PF13238           AAA_18         NaN
# 4    s  PF13401           AAA_22         NaN
# 5    s  PF12775            AAA_7         NaN
# 6    s  PF00308         Bac_DnaA  bac_dnaA;
# 7    s  PF06144   DNA_pol3_delta         NaN
# 8    s  PF13177  DNA_pol3_delta2         NaN
# 9    s  PF01695        IstB_IS21       IstB;
#
#                                          domain_name superfamily
# 0            Polyomavirus large T antigen C-terminus     AAA/SF3
# 1  ATPase family associated with various cellular...        AAA+
# 2                                  AAA ATPase domain        AAA+
# 3                                         AAA domain        AAA+
# 4                                         AAA domain        AAA+
# 5              P-loop containing dynein motor region        AAA+
# 6                            Bacterial dnaA  protein        AAA+
# 7                  DNA polymerase III, delta subunit        AAA+
# 8                  DNA polymerase III, delta subunit        AAA+
# 9                      IstB-like ATP binding protein        AAA+

# %%
add_identifiers(dists, d_up_mapping, d_up_info, d_pfam_hmm,
                 d_pfam_mapping, pf_to_suprf,
                 ploop_all_chains,pdbs_ploop)
# Out:
# No Uniprot ID,  5fhd A
# No Uniprot ID,  5fhd B
# No Uniprot ID,  5fhe A
# No Uniprot ID,  4qc2 A
# No Uniprot ID,  4qc2 B
# No Uniprot ID,  6tdu AA
# No Uniprot ID,  6tdu AB
# No Uniprot ID,  6tdu AC
# No Uniprot ID,  6tdu AF
# No Uniprot ID,  6tdu BA
# No Uniprot ID,  6tdu BB
# No Uniprot ID,  6tdu BC
# No Uniprot ID,  6tdu BF
# No Uniprot ID,  6tdy A
# No Uniprot ID,  6tdy B
# No Uniprot ID,  6tdy C
# No Uniprot ID,  6tdy F
# No Uniprot ID,  6tdz B
# No Uniprot ID,  6tdz C
# No Uniprot ID,  6tdz A
# No Uniprot ID,  6tdz D
# No Uniprot ID,  6te0 C
# No Uniprot ID,  6te0 A
# No Uniprot ID,  6te0 B
# No Uniprot ID,  6te0 E
# No Uniprot ID,  6gz3 Ct
# No Uniprot ID,  6gz4 Ct
# No Uniprot ID,  6gz5 Ct
# No Uniprot ID,  5it7 1
# No Uniprot ID,  3wyf A
# No Uniprot ID,  3wyf D
# No Uniprot ID,  5xoj A

# %%
mark_lowqual_sites(dists)
dists.to_csv(os.path.join(ploop_wdir,f"{year}_{spec}_t2_with_family.tsv"),sep="\t")
dists2=dists.copy()

# %% [markdown]
# Annotated dataframe looks like this:

# %%
dists.head()
# Out:
#   superfamily pfam_acc  pfam_domain                 domain_name Uniprot_Ac  \
# 0      TRAFAC  PF00063  Myosin_head  Myosin head (motor domain)     P10587
# 1      TRAFAC  PF00063  Myosin_head  Myosin head (motor domain)     P10587
# 2      TRAFAC  PF00063  Myosin_head  Myosin head (motor domain)     P10587
# 3      TRAFAC  PF00063  Myosin_head  Myosin head (motor domain)     P10587
# 4      TRAFAC  PF00063  Myosin_head  Myosin head (motor domain)     P10587
#
#     Uniprot_Id Protein_name_up Gene_name_up PDBID model nuc_type nuc_chain  \
# 0  MYH11_CHICK      Myosin-11         MYH11  1br1     0      ADP         A
# 1  MYH11_CHICK      Myosin-11         MYH11  1br1     0      ADP         C
# 2  MYH11_CHICK      Myosin-11         MYH11  1br1     0      ADP         E
# 3  MYH11_CHICK      Myosin-11         MYH11  1br1     0      ADP         G
# 4  MYH11_CHICK      Myosin-11         MYH11  1br2     0      ADP         A
#
#   nuc_id nuc_gamma_moiety_type nuc_gamma_moiety_chain nuc_gamma_moiety_id  \
# 0    998                   ALF                      A                 999
# 1    998                   ALF                      C                 999
# 2    998                   ALF                      E                 999
# 3    998                   ALF                      G                 999
# 4    998                   ALF                      A                 999
#
#   mg_in_site_4a_from_beta AG-site G-site TYPE_ARG LYS-site asn_TYPE  \
# 0                      MG     NaN    NaN      NaN      NaN
# 1                      MG     NaN    NaN      NaN      NaN
# 2                      MG     NaN    NaN      NaN      NaN
# 3                      MG     NaN    NaN      NaN      NaN
# 4                      MG     NaN    NaN      NaN      NaN
#
#   Lys_res_ch Lys_res_id nz-alpha-atom nz-alpha-dist nz-gamma-atom  \
# 0          A        250           O1A      8.639585            F4
# 1          C        250           O1A      8.718588            F4
# 2          E        250           O1A      8.767497            F4
# 3          G        250           O1A      8.785262            F4
# 4          A        250           O1A      8.386499            F4
#
#   nz-gamma-dist Arg_res_ch Arg_res_id nh1-alpha-atom nh1-alpha-dist  \
# 0      7.628103          A        247            O2A      10.024054
# 1      7.675519          C        247            O2A       9.955953
# 2      7.666852          E        247            O2A      10.116271
# 3      7.654045          G        247            O2A      10.132792
# 4      7.087786          A        247            O3A       9.803608
#
#   nh1-gamma-atom nh1-gamma-dist nh2-alpha-atom nh2-alpha-dist nh2-gamma-atom  \
# 0             F3        5.33214            O2A      11.278693             F3
# 1             F3       5.308627            O2A      11.298747             F3
# 2             F3       5.496902            O2A       11.47034             F3
# 3             F3       5.477052            O2A      11.498631             F3
# 4             F3       4.609398            O3A      12.066981             F3
#
#   nh2-gamma-dist ne-alpha-atom ne-alpha-dist ne-gamma-atom ne-gamma-dist  \
# 0       6.160625           O2A     10.615997            F3         6.615
# 1       6.233797           O2A     10.617236            F3       6.68114
# 2       6.434052           O2A      10.82166            F3       6.89429
# 3       6.433871           O2A     10.795943            F3      6.833364
# 4       6.799509           O2A     11.023004            F3      6.514483
#
#   asn_ID asn_ne2-alpha-atom asn_ne2-alpha-dist asn_ne2-gamma-atom  \
# 0   A242                O2A           2.916646                 F2
# 1   C242                O2A           2.969201                 F2
# 2   E242                O2A           3.156481                 F2
# 3   G242                O2A           3.129764                 F2
# 4   A242                O2A           2.941894                 F2
#
#   asn_ne2-gamma-dist                                          Surr_N_BB  \
# 0           3.817497             GLY_A468..F1(2.55); SER_A246..F2(2.70)
# 1           3.955435             GLY_C468..F1(2.46); SER_C246..F2(2.75)
# 2           3.965111  GLY_E468..F1(2.48); SER_E179..F1(3.99); SER_E2...
# 3           3.859841             GLY_G468..F1(2.53); SER_G246..F2(2.78)
# 4           3.716788             GLY_A468..F1(2.54); SER_A246..F2(2.58)
#
#   Surr_N_SCh gly13-chain gly13-type gly13-id nuc-to-g13-atom dist-gly13  \
# 0                      A        GLY      180              F1   3.655413
# 1                      C        GLY      180              F1   3.738719
# 2                      E        GLY      180              F1   3.665947
# 3                      G        GLY      180              F1   3.664732
# 4                      A        GLY      180              F3   3.980544
#
#   lys-ploop-info ploopk-dist resolution             method  \
# 0           A183    2.780986        3.5  x-ray diffraction
# 1           C183    2.751563        3.5  x-ray diffraction
# 2           E183    2.710544        3.5  x-ray diffraction
# 3           G183    2.774285        3.5  x-ray diffraction
# 4           A183    2.752079        2.9  x-ray diffraction
#
#                                              pdbname     pdbdate include  \
# 0  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 1  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 2  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 3  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN-ESSENTIAL LI...  1998-08-26     NaN
# 4  SMOOTH MUSCLE MYOSIN MOTOR DOMAIN COMPLEXED WI...  1998-08-26     NaN
#
#   SerK+1-Mg WB-Asp/Glu WBD-SerK+1_dist    WBD-Mg water_present is_hydro  \
# 0  2.159976   ASP_A465        3.946227  3.889449          True     True
# 1  2.166397   ASP_C465        3.922912  3.763648          True     True
# 2  2.076092   ASP_E465        3.938586  3.718373          True     True
# 3  2.066263   ASP_G465        3.922849  3.771162          True     True
# 4  2.013697   ASP_A465        2.795241  3.434139          True     True
#
#   preceding_res pfam_comm
# 0           LIG        Ok
# 1           LIG        Ok
# 2           LIG        Ok
# 3           LIG        Ok
# 4           LIG        Ok

# %% [markdown]
# ### 3.3 Lastly, Assign interaction type to finger residues

# %%
#Load table with sites we have checked manually
d_sites_checked=pd.read_csv(os.path.join(ploop_in_dir,sites_checked),sep="\t")
d_sites_checked.head()
# Out:
#     PDB   nuc   arg    argtype
# 0  1kof  B501  B124  NH2 weak*
# 1  1qhx  A501  A133  NH2 weak*
# 2  1wq1  R167  G789      FORK*
# 3  2bc9  A593   A48      FORK*
# 4  2g83  B355  B178  NH1 weak*

# %%
from pyploop.describe_finger import *

# %%
#Assign types only to "high-quality" sites
dists_selected=dists2[dists2.include.isna()].copy()
assign_arg_type(dists_selected, d_sites_checked)
assign_mono_type(dists_selected)
assign_type(dists_selected)
dists_selected.to_csv(os.path.join(ploop_wdir,f"{year}_{spec}_t3_dists_with_type_.tsv"), sep="\t")

# %%
dists_selected.tail()
# Out:
#      superfamily pfam_acc pfam_domain  \
# 3662      TRAFAC  PF02263         GBP
# 3663      TRAFAC  PF00350   Dynamin_N
# 3664      TRAFAC  PF00350   Dynamin_N
# 3665      TRAFAC  PF00350   Dynamin_N
# 3666      TRAFAC  PF00350   Dynamin_N
#
#                                        domain_name Uniprot_Ac    Uniprot_Id  \
# 3662  Guanylate-binding protein, N-terminal domain     Q8WXF7   ATLA1_HUMAN
# 3663                                Dynamin family     G0SFF0  G0SFF0_CHATD
# 3664                                Dynamin family     G0SFF0  G0SFF0_CHATD
# 3665                                Dynamin family     G0SFF0  G0SFF0_CHATD
# 3666                                Dynamin family     G0SFF0  G0SFF0_CHATD
#
#                Protein_name_up     Gene_name_up PDBID model nuc_type  \
# 3662               Atlastin-1   ATL1 GBP3 SPG3A  6b9f     0      GDP
# 3663  Putative sorting protein     CTHT_0061810  6djq     0      GDP
# 3664  Putative sorting protein     CTHT_0061810  6djq     0      GDP
# 3665  Putative sorting protein     CTHT_0061810  6djq     0      GDP
# 3666  Putative sorting protein     CTHT_0061810  6djq     0      GDP
#
#      nuc_chain nuc_id nuc_gamma_moiety_type nuc_gamma_moiety_chain  \
# 3662         B    506                   ALF                      B
# 3663         A   1001                   ALF                      A
# 3664         B   1001                   ALF                      B
# 3665         C   1001                   ALF                      C
# 3666         D   1001                   ALF                      D
#
#      nuc_gamma_moiety_id mg_in_site_4a_from_beta AG-site G-site TYPE_ARG  \
# 3662                 507                      MG     ARG   NONE     NH2.
# 3663                1002                      MG    NONE   NONE    NONE.
# 3664                1002                      MG    NONE   NONE    NONE.
# 3665                1002                      MG    NONE   NONE    NONE.
# 3666                1002                      MG    NONE   NONE    NONE.
#
#      LYS-site asn_TYPE Lys_res_ch Lys_res_id nz-alpha-atom  nz-alpha-dist  \
# 3662     NONE     NONE          B         78           O3A       9.275437
# 3663     NONE     NONE          A        240           O3A       6.848152
# 3664     NONE     NONE          B        240           O3A       5.680910
# 3665     NONE     NONE          C        240           O3A       7.143929
# 3666     NONE     NONE          D        240           O3A       6.579934
#
#      nz-gamma-atom  nz-gamma-dist Arg_res_ch Arg_res_id nh1-alpha-atom  \
# 3662            F1       9.620522          B         77            O1A
# 3663            F3       8.733605          A         71            O1A
# 3664            F3       8.498302          B         71            O2A
# 3665            F3       8.903456          C         71            O1A
# 3666            F3       8.465226          D         71            O2A
#
#       nh1-alpha-dist nh1-gamma-atom  nh1-gamma-dist nh2-alpha-atom  \
# 3662        4.430065             F4        4.947354            O1A
# 3663        7.048779             F4       10.524670            O1A
# 3664        6.883111             F1       11.194972            O2A
# 3665        7.163232             F4       10.982876            O1A
# 3666        6.032832             F1       10.871549            O2A
#
#       nh2-alpha-dist nh2-gamma-atom  nh2-gamma-dist ne-alpha-atom  \
# 3662        2.835662             F4        2.957734           O3A
# 3663        7.509537             F1       11.582500           O1A
# 3664        8.333436             F1       12.124759           O2A
# 3665        8.035327             F1       11.978857           O1A
# 3666        7.717821             F1       11.878605           O2A
#
#       ne-alpha-dist ne-gamma-atom  ne-gamma-dist asn_ID asn_ne2-alpha-atom  \
# 3662       4.683665            F1       2.908955   B177                O3A
# 3663       5.268142            F4       9.685854   B217                O3A
# 3664       6.163560            F4      10.001845   A217                O3A
# 3665       5.742301            F1      10.138892   D217                O3A
# 3666       5.749921            F4       9.888748   C217                O3A
#
#       asn_ne2-alpha-dist asn_ne2-gamma-atom  asn_ne2-gamma-dist  \
# 3662            7.003891                 F3            7.956620
# 3663            9.367575                 F3            7.095841
# 3664            9.179136                 F3            7.005194
# 3665            9.486238                 F3            7.203480
# 3666            9.348441                 F3            7.189288
#
#                                               Surr_N_BB Surr_N_SCh  \
# 3662  GLU_B119..F1(3.91); THR_B120..F2(3.59); GLY_B1...
# 3663  VAL_A76..F1(2.59); THR_A77..F1(2.98); GLY_A173...
# 3664  THR_B77..F1(3.01); VAL_B76..F1(2.72); GLY_B173...
# 3665  THR_C77..F1(3.10); VAL_C76..F1(2.58); GLY_C173...
# 3666  VAL_D76..F1(2.74); THR_D77..F1(2.96); GLY_D173...
#
#      gly13-chain gly13-type gly13-id nuc-to-g13-atom  dist-gly13  \
# 3662           B        ARG       77              F1    2.910028
# 3663           A        SER       53              F3    2.890800
# 3664           B        SER       53              F3    2.925606
# 3665           C        SER       53              F3    3.113955
# 3666           D        SER       53              F3    2.800873
#
#      lys-ploop-info  ploopk-dist resolution             method  \
# 3662            B80     2.570031        1.9  x-ray diffraction
# 3663            A56     2.572303        3.1  x-ray diffraction
# 3664            B56     2.678724        3.1  x-ray diffraction
# 3665            C56     2.577422        3.1  x-ray diffraction
# 3666            D56     2.705607        3.1  x-ray diffraction
#
#                                               pdbname     pdbdate include  \
# 3662      Human ATL1 mutant - F151S bound to GDPAlF4-  2017-10-10     NaN
# 3663  Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3664  Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3665  Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3666  Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
#
#      SerK+1-Mg WB-Asp/Glu WBD-SerK+1_dist    WBD-Mg water_present is_hydro  \
# 3662  2.148698   ASP_B146        2.667157  4.004481          True     True
# 3663  2.087833   ASP_A170        2.357399  3.649189          True    False
# 3664  2.138869   ASP_B170        2.477235  3.904188          True    False
# 3665   2.35699   ASP_C170        2.457356  4.060771          True    False
# 3666  2.096805   ASP_D170        2.442405  3.636164          True    False
#
#      preceding_res pfam_comm
# 3662           MLL        Ok
# 3663           VLT        Ok
# 3664           VLT        Ok
# 3665           VLT        Ok
# 3666           VLT        Ok

# %% [markdown]
# #### <i> A more compact version of the table for Supplementary </i>

# %%
dists_selected.index.name="Site_Id"
dists_selected.tail(5)
# Out:
#         superfamily pfam_acc pfam_domain  \
# Site_Id
# 3662         TRAFAC  PF02263         GBP
# 3663         TRAFAC  PF00350   Dynamin_N
# 3664         TRAFAC  PF00350   Dynamin_N
# 3665         TRAFAC  PF00350   Dynamin_N
# 3666         TRAFAC  PF00350   Dynamin_N
#
#                                           domain_name Uniprot_Ac  \
# Site_Id
# 3662     Guanylate-binding protein, N-terminal domain     Q8WXF7
# 3663                                   Dynamin family     G0SFF0
# 3664                                   Dynamin family     G0SFF0
# 3665                                   Dynamin family     G0SFF0
# 3666                                   Dynamin family     G0SFF0
#
#            Uniprot_Id           Protein_name_up     Gene_name_up PDBID model  \
# Site_Id
# 3662      ATLA1_HUMAN               Atlastin-1   ATL1 GBP3 SPG3A  6b9f     0
# 3663     G0SFF0_CHATD  Putative sorting protein     CTHT_0061810  6djq     0
# 3664     G0SFF0_CHATD  Putative sorting protein     CTHT_0061810  6djq     0
# 3665     G0SFF0_CHATD  Putative sorting protein     CTHT_0061810  6djq     0
# 3666     G0SFF0_CHATD  Putative sorting protein     CTHT_0061810  6djq     0
#
#         nuc_type nuc_chain nuc_id nuc_gamma_moiety_type  \
# Site_Id
# 3662         GDP         B    506                   ALF
# 3663         GDP         A   1001                   ALF
# 3664         GDP         B   1001                   ALF
# 3665         GDP         C   1001                   ALF
# 3666         GDP         D   1001                   ALF
#
#         nuc_gamma_moiety_chain nuc_gamma_moiety_id mg_in_site_4a_from_beta  \
# Site_Id
# 3662                         B                 507                      MG
# 3663                         A                1002                      MG
# 3664                         B                1002                      MG
# 3665                         C                1002                      MG
# 3666                         D                1002                      MG
#
#         AG-site G-site TYPE_ARG LYS-site asn_TYPE Lys_res_ch Lys_res_id  \
# Site_Id
# 3662        ARG   NONE     NH2.     NONE     NONE          B         78
# 3663       NONE   NONE    NONE.     NONE     NONE          A        240
# 3664       NONE   NONE    NONE.     NONE     NONE          B        240
# 3665       NONE   NONE    NONE.     NONE     NONE          C        240
# 3666       NONE   NONE    NONE.     NONE     NONE          D        240
#
#         nz-alpha-atom  nz-alpha-dist nz-gamma-atom  nz-gamma-dist Arg_res_ch  \
# Site_Id
# 3662              O3A       9.275437            F1       9.620522          B
# 3663              O3A       6.848152            F3       8.733605          A
# 3664              O3A       5.680910            F3       8.498302          B
# 3665              O3A       7.143929            F3       8.903456          C
# 3666              O3A       6.579934            F3       8.465226          D
#
#         Arg_res_id nh1-alpha-atom  nh1-alpha-dist nh1-gamma-atom  \
# Site_Id
# 3662            77            O1A        4.430065             F4
# 3663            71            O1A        7.048779             F4
# 3664            71            O2A        6.883111             F1
# 3665            71            O1A        7.163232             F4
# 3666            71            O2A        6.032832             F1
#
#          nh1-gamma-dist nh2-alpha-atom  nh2-alpha-dist nh2-gamma-atom  \
# Site_Id
# 3662           4.947354            O1A        2.835662             F4
# 3663          10.524670            O1A        7.509537             F1
# 3664          11.194972            O2A        8.333436             F1
# 3665          10.982876            O1A        8.035327             F1
# 3666          10.871549            O2A        7.717821             F1
#
#          nh2-gamma-dist ne-alpha-atom  ne-alpha-dist ne-gamma-atom  \
# Site_Id
# 3662           2.957734           O3A       4.683665            F1
# 3663          11.582500           O1A       5.268142            F4
# 3664          12.124759           O2A       6.163560            F4
# 3665          11.978857           O1A       5.742301            F1
# 3666          11.878605           O2A       5.749921            F4
#
#          ne-gamma-dist asn_ID asn_ne2-alpha-atom  asn_ne2-alpha-dist  \
# Site_Id
# 3662          2.908955   B177                O3A            7.003891
# 3663          9.685854   B217                O3A            9.367575
# 3664         10.001845   A217                O3A            9.179136
# 3665         10.138892   D217                O3A            9.486238
# 3666          9.888748   C217                O3A            9.348441
#
#         asn_ne2-gamma-atom  asn_ne2-gamma-dist  \
# Site_Id
# 3662                    F3            7.956620
# 3663                    F3            7.095841
# 3664                    F3            7.005194
# 3665                    F3            7.203480
# 3666                    F3            7.189288
#
#                                                  Surr_N_BB Surr_N_SCh  \
# Site_Id
# 3662     GLU_B119..F1(3.91); THR_B120..F2(3.59); GLY_B1...
# 3663     VAL_A76..F1(2.59); THR_A77..F1(2.98); GLY_A173...
# 3664     THR_B77..F1(3.01); VAL_B76..F1(2.72); GLY_B173...
# 3665     THR_C77..F1(3.10); VAL_C76..F1(2.58); GLY_C173...
# 3666     VAL_D76..F1(2.74); THR_D77..F1(2.96); GLY_D173...
#
#         gly13-chain gly13-type gly13-id nuc-to-g13-atom  dist-gly13  \
# Site_Id
# 3662              B        ARG       77              F1    2.910028
# 3663              A        SER       53              F3    2.890800
# 3664              B        SER       53              F3    2.925606
# 3665              C        SER       53              F3    3.113955
# 3666              D        SER       53              F3    2.800873
#
#         lys-ploop-info  ploopk-dist resolution             method  \
# Site_Id
# 3662               B80     2.570031        1.9  x-ray diffraction
# 3663               A56     2.572303        3.1  x-ray diffraction
# 3664               B56     2.678724        3.1  x-ray diffraction
# 3665               C56     2.577422        3.1  x-ray diffraction
# 3666               D56     2.705607        3.1  x-ray diffraction
#
#                                                  pdbname     pdbdate include  \
# Site_Id
# 3662         Human ATL1 mutant - F151S bound to GDPAlF4-  2017-10-10     NaN
# 3663     Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3664     Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3665     Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
# 3666     Vps1 GTPase-BSE fusion complexed with GDP.AlF4-  2018-05-25     NaN
#
#         SerK+1-Mg WB-Asp/Glu WBD-SerK+1_dist    WBD-Mg water_present is_hydro  \
# Site_Id
# 3662     2.148698   ASP_B146        2.667157  4.004481          True     True
# 3663     2.087833   ASP_A170        2.357399  3.649189          True    False
# 3664     2.138869   ASP_B170        2.477235  3.904188          True    False
# 3665      2.35699   ASP_C170        2.457356  4.060771          True    False
# 3666     2.096805   ASP_D170        2.442405  3.636164          True    False
#
#         preceding_res pfam_comm
# Site_Id
# 3662              MLL        Ok
# 3663              VLT        Ok
# 3664              VLT        Ok
# 3665              VLT        Ok
# 3666              VLT        Ok

# %%
from pyploop.table_features import format_for_excel

# %%
df_dist_formatted_for_excel=format_for_excel(dists_selected)
df_dist_formatted_for_excel.to_csv(os.path.join(ploop_wdir,f"{year}_{spec}_dists_FOR_XLSX.tsv"), sep="\t")
df_dist_formatted_for_excel.head(15)
# Out:
#         superfamily pfam_acc  pfam_domain   Uniprot_Id  \
# Site_Id
# 0            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 1            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 2            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 3            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 4            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 5            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 6            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 7            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 8            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 9            TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 10           TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 11           TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 12           TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 13           TRAFAC  PF00063  Myosin_head  MYH11_CHICK
# 16          RecA_F1  PF00006  ATP-synt_ab   ATPB_BOVIN
#
#                                    Protein_name_up PDBID resolution  \
# Site_Id
# 0                                       Myosin-11   1br1        3.5
# 1                                       Myosin-11   1br1        3.5
# 2                                       Myosin-11   1br1        3.5
# 3                                       Myosin-11   1br1        3.5
# 4                                       Myosin-11   1br2        2.9
# 5                                       Myosin-11   1br2        2.9
# 6                                       Myosin-11   1br2        2.9
# 7                                       Myosin-11   1br2        2.9
# 8                                       Myosin-11   1br2        2.9
# 9                                       Myosin-11   1br2        2.9
# 10                                      Myosin-11   1br4       3.62
# 11                                      Myosin-11   1br4       3.62
# 12                                      Myosin-11   1br4       3.62
# 13                                      Myosin-11   1br4       3.62
# 16       ATP synthase subunit beta, mitochondrial   1e1r       2.48
#
#                     method nucleotide_type nucleotide_id model  \
# Site_Id
# 0        x-ray diffraction         ADP-ALF          A998     0
# 1        x-ray diffraction         ADP-ALF          C998     0
# 2        x-ray diffraction         ADP-ALF          E998     0
# 3        x-ray diffraction         ADP-ALF          G998     0
# 4        x-ray diffraction         ADP-ALF          A998     0
# 5        x-ray diffraction         ADP-ALF          B998     0
# 6        x-ray diffraction         ADP-ALF          C998     0
# 7        x-ray diffraction         ADP-ALF          D998     0
# 8        x-ray diffraction         ADP-ALF          E998     0
# 9        x-ray diffraction         ADP-ALF          F998     0
# 10       x-ray diffraction         ADP-BEF          A998     0
# 11       x-ray diffraction         ADP-BEF          C998     0
# 12       x-ray diffraction         ADP-BEF          E998     0
# 13       x-ray diffraction         ADP-BEF          G998     0
# 16       x-ray diffraction         ADP-AF3          D600     0
#
#         mg_in_site_4a_from_beta AG-site G-site lys_id LYS-site nz-alpha-atom  \
# Site_Id
# 0                            MG     ASN   NONE   A250     NONE           O1A
# 1                            MG     ASN   NONE   C250     NONE           O1A
# 2                            MG     ASN   NONE   E250     NONE           O1A
# 3                            MG     ASN   NONE   G250     NONE           O1A
# 4                            MG     ASN   NONE   A250     NONE           O1A
# 5                            MG     ASN   NONE   B250     NONE           O1A
# 6                            MG     ASN   NONE   C250     NONE           O1A
# 7                            MG     ASN   NONE   D250     NONE           O1A
# 8                            MG     ASN   NONE   E250     NONE           O1A
# 9                            MG     ASN   NONE   F250     NONE           O1A
# 10                           MG     ASN   NONE   A250     NONE           O2A
# 11                           MG     ASN   NONE   C250     NONE           O2A
# 12                           MG     ASN   NONE   E250     NONE           O2A
# 13                           MG     ASN   NONE   G250     NONE           O2A
# 16                           MG     ARG   1ARG   C391     NONE           O3A
#
#          nz-alpha-dist nz-gamma-atom  nz-gamma-dist arg_id TYPE_ARG  \
# Site_Id
# 0             8.639585            F4       7.628103   A247    NONE.
# 1             8.718588            F4       7.675519   C247    NONE.
# 2             8.767497            F4       7.666852   E247    NONE.
# 3             8.785262            F4       7.654045   G247    NONE.
# 4             8.386499            F4       7.087786   A247    NONE.
# 5             8.408330            F4       7.236110   B247    NONE.
# 6             8.460630            F4       7.155810   C247    NONE.
# 7             8.384240            F4       7.226902   D247    NONE.
# 8             8.411736            F4       7.183222   E247    NONE.
# 9             8.376718            F4       7.212440   F247    NONE.
# 10            8.790961            F3       7.873165   A247    NONE.
# 11            8.889592            F3       7.892871   C247    NONE.
# 12            8.874241            F3       7.902951   E247    NONE.
# 13            8.876913            F3       7.900444   G247    NONE.
# 16           11.738802            F1      13.986131   C373     NH1.
#
#         nh1-alpha-atom  nh1-alpha-dist nh1-gamma-atom  nh1-gamma-dist  \
# Site_Id
# 0                  O2A       10.024054             F3        5.332140
# 1                  O2A        9.955953             F3        5.308627
# 2                  O2A       10.116271             F3        5.496902
# 3                  O2A       10.132792             F3        5.477052
# 4                  O3A        9.803608             F3        4.609398
# 5                  O3A        9.711628             F3        4.545388
# 6                  O3A        9.787507             F3        4.580737
# 7                  O3A        9.689243             F3        4.517084
# 8                  O2A        9.792457             F3        4.501697
# 9                  O2A        9.781414             F3        4.509281
# 10                 O2A       10.543421             F2        5.984653
# 11                 O2A       10.647289             F2        6.082127
# 12                 O2A       10.649657             F2        6.093245
# 13                 O2A       10.641304             F2        6.084043
# 16                 O2A        2.973341             F3        2.980349
#
#         nh2-alpha-atom  nh2-alpha-dist nh2-gamma-atom  nh2-gamma-dist  \
# Site_Id
# 0                  O2A       11.278693             F3        6.160625
# 1                  O2A       11.298747             F3        6.233797
# 2                  O2A       11.470340             F3        6.434052
# 3                  O2A       11.498631             F3        6.433871
# 4                  O3A       12.066981             F3        6.799509
# 5                  O3A       11.985205             F3        6.734874
# 6                  O3A       12.043881             F3        6.769961
# 7                  O3A       11.947335             F3        6.694661
# 8                  O2A       12.063276             F3        6.689701
# 9                  O2A       12.049294             F3        6.697526
# 10                 O2A       12.475974             F2        7.758894
# 11                 O2A       12.571443             F2        7.848627
# 12                 O2A       12.576156             F2        7.859106
# 13                 O2A       12.567819             F2        7.849726
# 16                 O3A        4.527612             F1        2.822212
#
#         ne-alpha-atom  ne-alpha-dist ne-gamma-atom  ne-gamma-dist asn_ID  \
# Site_Id
# 0                 O2A      10.615997            F3       6.615000   A242
# 1                 O2A      10.617236            F3       6.681140   C242
# 2                 O2A      10.821660            F3       6.894290   E242
# 3                 O2A      10.795943            F3       6.833364   G242
# 4                 O2A      11.023004            F3       6.514483   A242
# 5                 O2A      10.912102            F3       6.481107   B242
# 6                 O2A      11.005755            F3       6.470978   C242
# 7                 O2A      10.901466            F3       6.465443   D242
# 8                 O2A      10.941878            F3       6.426057   E242
# 9                 O2A      10.925579            F3       6.439191   F242
# 10                O2A      11.614105            F2       7.607683   A242
# 11                O2A      11.713080            F2       7.693230   C242
# 12                O2A      11.714905            F2       7.703091   E242
# 13                O2A      11.707720            F2       7.695547   G242
# 16                O2A       4.199194            F1       4.664546   D257
#
#         asn_TYPE asn_ne2-alpha-atom  asn_ne2-alpha-dist asn_ne2-gamma-atom  \
# Site_Id
# 0        AG_weak                O2A            2.916646                 F2
# 1        AG_weak                O2A            2.969201                 F2
# 2        AG_weak                O2A            3.156481                 F2
# 3        AG_weak                O2A            3.129764                 F2
# 4        AG_weak                O2A            2.941894                 F2
# 5        AG_weak                O2A            2.807305                 F2
# 6        AG_weak                O2A            2.857830                 F2
# 7        AG_weak                O2A            2.823901                 F2
# 8        AG_weak                O2A            2.875510                 F2
# 9        AG_weak                O2A            2.883935                 F2
# 10       AG_weak                O2A            3.934883                 F2
# 11       AG_weak                O2A            3.964873                 F2
# 12       AG_weak                O2A            3.977866                 F2
# 13       AG_weak                O2A            3.969061                 F2
# 16          NONE                O3A            8.537187                 F2
#
#          asn_ne2-gamma-dist  \
# Site_Id
# 0                  3.817497
# 1                  3.955435
# 2                  3.965111
# 3                  3.859841
# 4                  3.716788
# 5                  3.755559
# 6                  3.609300
# 7                  3.815986
# 8                  3.830085
# 9                  3.827353
# 10                 2.882805
# 11                 2.787829
# 12                 2.774986
# 13                 2.787919
# 16                 5.387968
#
#                                                  Surr_N_BB  \
# Site_Id
# 0                   GLY_A468..F1(2.55); SER_A246..F2(2.70)
# 1                   GLY_C468..F1(2.46); SER_C246..F2(2.75)
# 2        GLY_E468..F1(2.48); SER_E179..F1(3.99); SER_E2...
# 3                   GLY_G468..F1(2.53); SER_G246..F2(2.78)
# 4                   GLY_A468..F1(2.54); SER_A246..F2(2.58)
# 5                   GLY_B468..F1(2.43); SER_B246..F2(2.62)
# 6                   GLY_C468..F1(2.62); SER_C246..F2(2.55)
# 7                   GLY_D468..F1(2.40); SER_D246..F2(2.62)
# 8                   GLY_E468..F1(2.46); SER_E246..F2(2.57)
# 9                   GLY_F468..F1(2.47); SER_F246..F2(2.57)
# 10       GLY_A468..F1(3.11); SER_A179..F1(3.89); SER_A2...
# 11       GLY_C468..F1(3.22); SER_C179..F1(3.87); SER_C2...
# 12       GLY_E468..F1(3.24); SER_E179..F1(3.86); SER_E2...
# 13       SER_G179..F1(3.86); GLY_G468..F1(3.21); SER_G2...
# 16                                      SER_C344..F1(3.61)
#
#                      Surr_N_SCh     gly13 nuc-to-g13-atom  dist-gly13  \
# Site_Id
# 0                                GLY A180              F1    3.655413
# 1                                GLY C180              F1    3.738719
# 2                                GLY E180              F1    3.665947
# 3                                GLY G180              F1    3.664732
# 4                                GLY A180              F3    3.980544
# 5                                GLY B180              F3    4.008591
# 6                                GLY C180              F3    3.942289
# 7                                GLY D180              F3    4.026449
# 8                                GLY E180              F3    4.025989
# 9                                GLY F180              F3    4.008728
# 10                               GLY A180              F2    3.435373
# 11                               GLY C180              F2    3.347744
# 12                               GLY E180              F2    3.337886
# 13                               GLY G180              F2    3.334381
# 16       ARG_D189_NH1..F3(2.96)  GLY D159              F1    3.430842
#
#         lys-ploop-info  ploopk-dist SerK+1-Mg WB-Asp/Glu WBD-SerK+1_dist  \
# Site_Id
# 0                 A183     2.780986  2.159976   ASP_A465        3.946227
# 1                 C183     2.751563  2.166397   ASP_C465        3.922912
# 2                 E183     2.710544  2.076092   ASP_E465        3.938586
# 3                 G183     2.774285  2.066263   ASP_G465        3.922849
# 4                 A183     2.752079  2.013697   ASP_A465        2.795241
# 5                 B183     2.634789  2.177655   ASP_B465        2.802485
# 6                 C183     2.830580  2.067558   ASP_C465        2.815989
# 7                 D183     2.592428  2.151943   ASP_D465        2.802868
# 8                 E183     2.768176  2.075293   ASP_E465        2.807995
# 9                 F183     2.715567  2.071716   ASP_F465        2.809554
# 10                A183     3.243134  2.467455   ASP_A465        3.627793
# 11                C183     3.324747  2.407644   ASP_C465        3.630804
# 12                E183     3.343595  2.417112   ASP_E465        3.631684
# 13                G183     3.320496  2.420111   ASP_G465        3.630344
# 16                D162     2.980699  2.152539   ASP_D256        2.428535
#
#            WBD-Mg is_hydro preceding_res water_present
# Site_Id
# 0        3.889449     True           LIG          True
# 1        3.763648     True           LIG          True
# 2        3.718373     True           LIG          True
# 3        3.771162     True           LIG          True
# 4        3.434139     True           LIG          True
# 5        3.405205     True           LIG          True
# 6        3.559766     True           LIG          True
# 7        3.383194     True           LIG          True
# 8        3.319242     True           LIG          True
# 9        3.334862     True           LIG          True
# 10       3.519642     True           LIG          True
# 11       3.588267     True           LIG          True
# 12       3.584695     True           LIG          True
# 13       3.582038     True           LIG          True
# 16       4.011002     True           IFL          True

# %%
pdbs_ploop
# Out:
#        PDB_ID CHAIN_ID    2    PFAM_Name PFAM_ACC Accesion Position pdb_id
# 367838   5HCI        A  NaN   ATP_bind_1  PF03029   P47122    8-258   5hci
# 367839   5HCI        D  NaN   ATP_bind_1  PF03029   P47122    8-258   5hci
# 367840   5HCI        E  NaN   ATP_bind_1  PF03029   P47122    8-258   5hci
# 367841   5HCI        F  NaN   ATP_bind_1  PF03029   P47122    8-258   5hci
# 367842   5HCI        C  NaN   ATP_bind_1  PF03029   P47122    8-258   5hci
# ...       ...      ...  ...          ...      ...      ...      ...    ...
# 388775   4ETP        B  NaN  Microtub_bd  PF16796   Q12045  354-494   4etp
# 388776   4GKQ        A  NaN  Microtub_bd  PF16796   Q6FSG8  303-440   4gkq
# 388777   4GKQ        B  NaN  Microtub_bd  PF16796   Q6FSG8  311-440   4gkq
# 388778   4GKP        A  NaN  Microtub_bd  PF16796   Q6FSG8  325-440   4gkp
# 388779   4GKP        B  NaN  Microtub_bd  PF16796   Q6FSG8  313-440   4gkp
#
# [18383 rows x 8 columns]
